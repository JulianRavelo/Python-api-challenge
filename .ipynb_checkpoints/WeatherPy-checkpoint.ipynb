# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
print(tuple(lat_lngs))
# Out:
# Number of cities in the list: 584
# ()

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    params = {
        "appid":weather_api_key,
        "units":"metric"
    }
    
    query_url = url + city
    response = requests.get(url + city, params=params).json()

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = response["weather"][0]["description"]

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_max_temp = response["main"]["temp_max"]
        city_humidity = response["main"]["humidity"]
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_date = response["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gizo
# Processing Record 2 of Set 1 | vorgashor
# Processing Record 3 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 1 | zhezqazghan
# Processing Record 5 of Set 1 | nanzhang chengguanzhen
# Processing Record 6 of Set 1 | tazovsky
# Processing Record 7 of Set 1 | margaret river
# Processing Record 8 of Set 1 | itoman
# Processing Record 9 of Set 1 | whangarei
# Processing Record 10 of Set 1 | richards bay
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | agua dulce
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | papatowai
# Processing Record 17 of Set 1 | waitangi
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | bratsk
# Processing Record 20 of Set 1 | donskoy
# Processing Record 21 of Set 1 | kayyerkan
# Processing Record 22 of Set 1 | dunedin
# Processing Record 23 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 24 of Set 1 | okhotsk
# Processing Record 25 of Set 1 | hailun
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | grants
# Processing Record 28 of Set 1 | grytviken
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | blackmans bay
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | anadyr
# Processing Record 33 of Set 1 | edinburgh of the seven seas
# Processing Record 34 of Set 1 | wailua homesteads
# Processing Record 35 of Set 1 | port-aux-francais
# Processing Record 36 of Set 1 | aasiaat
# Processing Record 37 of Set 1 | ves'yegonsk
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | fuding
# Processing Record 40 of Set 1 | stanley
# Processing Record 41 of Set 1 | adamstown
# Processing Record 42 of Set 1 | sao vicente
# Processing Record 43 of Set 1 | flying fish cove
# Processing Record 44 of Set 1 | guangyuan
# Processing Record 45 of Set 1 | fomboni
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | hawaiian paradise park
# Processing Record 0 of Set 2 | slavutych
# Processing Record 1 of Set 2 | vadso
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | shimoda
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | nar'yan-mar
# Processing Record 7 of Set 2 | malabar
# Processing Record 8 of Set 2 | ijuw
# City not found. Skipping...
# Processing Record 9 of Set 2 | alesund
# Processing Record 10 of Set 2 | mvurwi
# Processing Record 11 of Set 2 | haiku-pauwela
# Processing Record 12 of Set 2 | utrik
# Processing Record 13 of Set 2 | colonia
# Processing Record 14 of Set 2 | fujin
# Processing Record 15 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record
# Processing Record 8 of Set 5 | atafu village
# Processing Record 9 of Set 5 | jiayuguan
# Processing Record 10 of Set 5 | mournies
# Processing Record 11 of Set 5 | hirson
# Processing Record 12 of Set 5 | sarkand
# Processing Record 13 of Set 5 | silistra
# Processing Record 14 of Set 5 | nizhnesortymskiy
# Processing Record 15 of Set 5 | coahuayana de hidalgo
# Processing Record 16 of Set 5 | tocopilla
# Processing Record 17 of Set 5 | tura
# Processing Record 18 of Set 5 | conception bay south
# Processing Record 19 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 20 of Set 5 | enewetak
# Processing Record 21 of Set 5 | sandnessjoen
# Processing Record 22 of Set 5 | kertih
# Processing Record 23 of Set 5 | hector caballero
# City not found. Skipping...
# Processing Record 24 of Set 5 | narrabri
# Processing Record 25 of Set 5 | balykshi
# Processing Record 26 of Set 5 | santiago de cao
# Processing Record 27 of Set 5 | jiamusi
# Processing Record 28 of Set 5 | remire-montjoly
# Processing Record 29 of Set 5 | usogorsk
# Processing Record 30 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 31 of Set 5 | palu
# Processing Record 32 of Set 5 | saldanha
# Processing Record 33 of Set 5 | vikulovo
# Processing Record 34 of Set 5 | la'ie
# Processing Record 35 of Set 5 | kerema
# Processing Record 36 of Set 5 | warrnambool
# Processing Record 37 of Set 5 | nova vicosa
# Processing Record 38 of Set 5 | kocaali
# Processing Record 39 of Set 5 | altai
# Processing Record 40 of Set 5 | 'aqrah
# City not found. Skipping...
# Processing Record 41 of Set 5 | ribeira grande
# Processing Record 42 of Set 5 | meadow lakes
# Processing Record 43 of Set 5 | adra
# Processing Record 44 of Set 5 | namibe
# Processing Record 45 of Set 5 | kerikeri
# Processing Record 46 of Set 5 | lampazos de naranjo
# Processing Record 47 of Set 5 | sitka
# Processing Record 48 of Set 5 | congonhas
# Processing Record 49 of Set 5 | puerto deseado
# Processing Record 0 of Set 6 | pingnan
# Processing Record 1 of Set 6 | kapa'a
# Processing Record 2 of Set 6 | selfoss
# Processing Record 3 of Set 6 | revda
# Processing Record 4 of Set 6 | imatra
# Processing Record 5 of Set 6 | al burayqah
# Processing Record 6 of Set 6 | rantepao
# Processing Record 7 of Set 6 | leeton
# Processing Record 8 of Set 6 | carnarvon
# Processing Record 9 of Set 6 | gamba
# Processing Record 10 of Set 6 | kirkwood
# Processing Record 11 of Set 6 | kailua-kona
# Processing Record 12 of Set 6 | pskov
# Processing Record 13 of Set 6 | portland
# Processing Record 14 of Set 6 | yagry
# City not found. Skipping...
# Processing Record 15 of Set 6 | namsos
# Processing Record 16 of Set 6 | inarajan village
# Processing Record 17 of Set 6 | sinabang
# Processing Record 18 of Set 6 | tosontsengel
# Processing Record 19 of Set 6 | san rafael del sur
# Processing Record 20 of Set 6 | soderhamn
# Processing Record 21 of Set 6 | kruisfontein
# Processing Record 22 of Set 6 | newport
# Processing Record 23 of Set 6 | kuanda
# Processing Record 24 of Set 6 | brak
# Processing Record 25 of Set 6 | klyuchi
# Processing Record 26 of Set 6 | labytnangi
# Processing Record 27 of Set 6 | kirakira
# Processing Record 28 of Set 6 | suntar
# Processing Record 29 of Set 6 | labrador city
# Processing Record 30 of Set 6 | hohr-grenzhausen
# Processing Record 31 of Set 6 | ust-nera
# Processing Record 32 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 6 | qamdo
# Processing Record 34 of Set 6 | mount isa
# Processing Record 35 of Set 6 | west valley
# Processing Record 36 of Set 6 | lindsay
# Processing Record 37 of Set 6 | ipilan
# Processing Record 38 of Set 6 | sonari
# Processing Record 39 of Set 6 | zhangjiakou shi xuanhua qu
# Processing Record 40 of Set 6 | prado
# Processing Record 41 of Set 6 | narra
# Processing Record 42 of Set 6 | la passe
# Processing Record 43 of Set 6 | priargunsk
# Processing Record 44 of Set 6 | luce
# Processing Record 45 of Set 6 | capayan
# Processing Record 46 of Set 6 | manicore
# Processing Record 47 of Set 6 | ingeniero jacobacci
# Processing Record 48 of Set 6 | papao
# Processing Record 49 of Set 6 | el granada
# Processing Record 0 of Set 7 | challapata
# Processing Record 1 of Set 7 | rio grande
# Processing Record 2 of Set 7 | aiquile
# Processing Record 3 of Set 7 | oum hadjer
# Processing Record 4 of Set 7 | saint-pierre
# Processing Record 5 of Set 7 | phan thiet
# Processing Record 6 of Set 7 | san sebastian de la gomera
# Processing Record 7 of Set 7 | kimbe
# Processing Record 8 of Set 7 | kingston
# Processing Record 9 of Set 7 | fort mcmurray
# Processing Record 10 of Set 7 | ararangua
# Processing Record 11 of Set 7 | salinas
# Processing Record 12 of Set 7 | cockburn town
# Processing Record 13 of Set 7 | khandyga
# Processing Record 14 of Set 7 | steamboat springs
# Processing Record 15 of Set 7 | omdurman
# Processing Record 16 of Set 7 | lerwick
# Processing Record 17 of Set 7 | rapid city
# Processing Record 18 of Set 7 | egilsstadir
# Processing Record 19 of Set 7 | westport
# Processing Record 20 of Set 7 | kiunga
# Processing Record 21 of Set 7 | ola
# Processing Record 22 of Set 7 | puerto santa
# Processing Record 23 of Set 7 | myshkin
# Processing Record 24 of Set 7 | dubbo
# Processing Record 25 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 26 of Set 7 | san jose del cabo
# Processing Record 27 of Set 7 | olyokminsk
# Processing Record 28 of Set 7 | sarwar
# Processing Record 29 of Set 7 | bei'an
# Processing Record 30 of Set 7 | taltal
# Processing Record 31 of Set 7 | nadi
# Processing Record 32 of Set 7 | cumbal
# Processing Record 33 of Set 7 | hobyo
# Processing Record 34 of Set 7 | severobaykal'sk
# Processing Record 35 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 36 of Set 7 | pascagoula
# Processing Record 37 of Set 7 | bawku
# Processing Record 38 of Set 7 | calipatria
# Processing Record 39 of Set 7 | ancud
# Processing Record 40 of Set 7 | pudozh
# Processing Record 41 of Set 7 | rawson
# Processing Record 42 of Set 7 | portel
# Processing Record 43 of Set 7 | bubanza
# Processing Record 44 of Set 7 | cabo san lucas
# Processing Record 45 of Set 7 | vila franca do campo
# Processing Record 46 of Set 7 | arteche
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | belvedere marittimo
# Processing Record 49 of Set 7 | sierra grande
# Processing Record 22 of Set 9 | kudahuvadhoo
# Processing Record 23 of Set 9 | cestos city
# Processing Record 24 of Set 9 | santa elena de uairen
# Processing Record 25 of Set 9 | calama
# Processing Record 26 of Set 9 | al fqih ben calah
# Processing Record 27 of Set 9 | cidreira
# Processing Record 28 of Set 9 | kavaratti
# Processing Record 29 of Set 9 | vilyuchinsk
# Processing Record 30 of Set 9 | rajanpur
# Processing Record 31 of Set 9 | callao
# Processing Record 32 of Set 9 | sur
# Processing Record 33 of Set 9 | tsuma
# Processing Record 34 of Set 9 | ko pha ngan
# Processing Record 35 of Set 9 | bardai
# Processing Record 36 of Set 9 | aykhal
# Processing Record 37 of Set 9 | kindu
# Processing Record 38 of Set 9 | island harbour
# Processing Record 39 of Set 9 | hoxtolgay
# City not found. Skipping...
# Processing Record 40 of Set 9 | steinbach
# Processing Record 41 of Set 9 | kiama
# Processing Record 42 of Set 9 | broome
# Processing Record 43 of Set 9 | sao gabriel da cachoeira
# Processing Record 44 of Set 9 | bamboo flat
# Processing Record 45 of Set 9 | manismata
# Processing Record 46 of Set 9 | lethbridge
# Processing Record 47 of Set 9 | tofol
# Processing Record 48 of Set 9 | novyy rogachik
# Processing Record 49 of Set 9 | puerto aysen
# Processing Record 0 of Set 10 | glace bay
# Processing Record 1 of Set 10 | castillos
# Processing Record 2 of Set 10 | fauske
# Processing Record 3 of Set 10 | tot'ma
# Processing Record 4 of Set 10 | horta
# Processing Record 5 of Set 10 | cacador
# Processing Record 6 of Set 10 | pyt-yakh
# Processing Record 7 of Set 10 | lagunillas
# Processing Record 8 of Set 10 | san jose village
# City not found. Skipping...
# Processing Record 9 of Set 10 | petalcingo
# Processing Record 10 of Set 10 | lianhe
# Processing Record 11 of Set 10 | nuku'alofa
# Processing Record 12 of Set 10 | erenhot
# Processing Record 13 of Set 10 | nawa
# Processing Record 14 of Set 10 | luanda
# Processing Record 15 of Set 10 | polyarnyy
# Processing Record 16 of Set 10 | ratangarh
# Processing Record 17 of Set 10 | lake in the hills
# Processing Record 18 of Set 10 | pandan
# Processing Record 19 of Set 10 | agenebode
# Processing Record 20 of Set 10 | ulan bator
# Processing Record 21 of Set 10 | malvan
# Processing Record 22 of Set 10 | patterson
# Processing Record 23 of Set 10 | al bardiyah
# Processing Record 24 of Set 10 | boa vista
# Processing Record 25 of Set 10 | quzhou
# Processing Record 26 of Set 10 | novodvinsk
# Processing Record 27 of Set 10 | weno
# Processing Record 28 of Set 10 | angel r. cabada
# Processing Record 29 of Set 10 | port saint john's
# Processing Record 30 of Set 10 | juneau
# Processing Record 31 of Set 10 | chui
# Processing Record 32 of Set 10 | hafar al-batin
# Processing Record 33 of Set 10 | ocean city
# Processing Record 34 of Set 10 | oran
# Processing Record 35 of Set 10 | val-des-monts
# Processing Record 36 of Set 10 | akwanga
# Processing Record 37 of Set 10 | hachinohe
# Processing Record 38 of Set 10 | ar rutbah
# Processing Record 39 of Set 10 | alice springs
# Processing Record 40 of Set 10 | tando adam
# Processing Record 41 of Set 10 | manokwari
# Processing Record 42 of Set 10 | talcahuano
# Processing Record 43 of Set 10 | el calafate
# Processing Record 44 of Set 10 | port hedland
# Processing Record 45 of Set 10 | bayji
# Processing Record 46 of Set 10 | kill devil hills
# Processing Record 47 of Set 10 | fale old settlement
# Processing Record 48 of Set 10 | caldwell
# Processing Record 49 of Set 10 | ulladulla
# Processing Record 0 of Set 11 | neryungri
# Processing Record 1 of Set 11 | hilo
# Processing Record 2 of Set 11 | tchintabaraden
# Processing Record 3 of Set 11 | penzance
# Processing Record 4 of Set 11 | floro
# Processing Record 5 of Set 11 | plastun
# Processing Record 6 of Set 11 | pante makasar
# City not found. Skipping...
# Processing Record 7 of Set 11 | prince rupert
# Processing Record 8 of Set 11 | happy valley-goose bay
# Processing Record 9 of Set 11 | turkmenabat
# Processing Record 10 of Set 11 | askoy
# Processing Record 11 of Set 11 | vilcun
# Processing Record 12 of Set 11 | mokhsogollokh
# Processing Record 13 of Set 11 | san juan
# Processing Record 14 of Set 11 | kavieng
# Processing Record 15 of Set 11 | new norfolk
# Processing Record 16 of Set 11 | pizarro
# Processing Record 17 of Set 11 | yei
# Processing Record 18 of Set 11 | amos
# Processing Record 19 of Set 11 | ouellah
# City not found. Skipping...
# Processing Record 20 of Set 11 | wschowa
# Processing Record 21 of Set 11 | sao felix do xingu
# Processing Record 22 of Set 11 | ha giang
# Processing Record 23 of Set 11 | lichinga
# Processing Record 24 of Set 11 | penonome
# Processing Record 25 of Set 11 | camocim
# Processing Record 26 of Set 11 | diu
# Processing Record 27 of Set 11 | kuta
# Processing Record 28 of Set 11 | cooma
# Processing Record 29 of Set 11 | portage la prairie
# Processing Record 30 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 31 of Set 11 | nuuk
# Processing Record 32 of Set 11 | el alto
# Processing Record 33 of Set 11 | zagora
# Processing Record 34 of Set 11 | ouargla
# Processing Record 35 of Set 11 | arbus
# Processing Record 36 of Set 11 | sona
# Processing Record 37 of Set 11 | mountain home
# Processing Record 38 of Set 11 | baotou
# Processing Record 39 of Set 11 | mana
# Processing Record 40 of Set 11 | kunming
# Processing Record 41 of Set 11 | brooks
# Processing Record 42 of Set 11 | kousa
# Processing Record 43 of Set 11 | bubaque
# Processing Record 44 of Set 11 | raholt
# Processing Record 45 of Set 11 | borgarnes
# Processing Record 46 of Set 11 | praia da vitoria
# Processing Record 47 of Set 11 | lensk
# Processing Record 48 of Set 11 | nantucket
# Processing Record 49 of Set 11 | annau
# Processing Record 0 of Set 12 | morden
# Processing Record 1 of Set 12 | jalai nur
# Processing Record 2 of Set 12 | sisimiut
# Processing Record 3 of Set 12 | zheleznogorsk
# Processing Record 4 of Set 12 | brisas de zicatela
# Processing Record 5 of Set 12 | taulaga
# Processing Record 6 of Set 12 | egersund
# Processing Record 7 of Set 12 | lihue
# Processing Record 8 of Set 12 | villa gesell
# Processing Record 9 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 10 of Set 12 | san antonio
# Processing Record 11 of Set 12 | manaure balcon del cesar
# Processing Record 12 of Set 12 | chadan
# Processing Record 13 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 14 of Set 12 | buala
# Processing Record 15 of Set 12 | brandon
# Processing Record 16 of Set 12 | dwarka
# Processing Record 17 of Set 12 | marsh harbour
# Processing Record 18 of Set 12 | vikhorevka
# Processing Record 19 of Set 12 | san fernando
# Processing Record 20 of Set 12 | chebba
# Processing Record 21 of Set 12 | tianshui
# Processing Record 22 of Set 12 | goianinha
# Processing Record 23 of Set 12 | ambodifotatra
# Processing Record 24 of Set 12 | prince george
# Processing Record 25 of Set 12 | constantia
# Processing Record 26 of Set 12 | bayan nur
# City not found. Skipping...
# Processing Record 27 of Set 12 | nogliki
# Processing Record 28 of Set 12 | nikolayevsk-on-amure
# Processing Record 29 of Set 12 | saham
# Processing Record 30 of Set 12 | lembar
# City not found. Skipping...
# Processing Record 31 of Set 12 | miquelon
# Processing Record 32 of Set 12 | smithers
# Processing Record 33 of Set 12 | veraval
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data

city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                    gizo  -8.1030  156.8419     26.50        83         100
# 1               vorgashor  67.5833   63.9500     10.56        72          96
# 2             zhezqazghan  47.7833   67.7667     20.32        30          75
# 3  nanzhang chengguanzhen  31.7839  111.8275     24.86        74          59
# 4                tazovsky  67.4667   78.7000     12.20        71          62
#
#    Wind Speed Country        Date
# 0        8.31      SB  1693217548
# 1        3.98      RU  1693217550
# 2        9.00      KZ  1693217552
# 3        1.74      CN  1693217553
# 4        2.58      RU  1693217554

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
date = datetime.date.fromtimestamp(city_data_df["Date"][0])
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          gizo  -8.1030  156.8419     26.50        83
# 1                     vorgashor  67.5833   63.9500     10.56        72
# 2                   zhezqazghan  47.7833   67.7667     20.32        30
# 3        nanzhang chengguanzhen  31.7839  111.8275     24.86        74
# 4                      tazovsky  67.4667   78.7000     12.20        71
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        8.31      SB  1693217548
# 1                96        3.98      RU  1693217550
# 2                75        9.00      KZ  1693217552
# 3                59        1.74      CN  1693217553
# 4                62        2.58      RU  1693217554

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Max Temp"]
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.ylabel("Max Temperature (°C)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs Max Temperature ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Humidity"]
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs Humidity ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Cloudiness"]
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs Cloudiness ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Wind Speed"]
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs Wind Speed ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
y_values = city_data_df["Lat"]
x_values = city_data_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
line_eq
# Out:
# 'y = -1.68x + 26.26'

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                     vorgashor  67.5833   63.9500     10.56        72
# 2                   zhezqazghan  47.7833   67.7667     20.32        30
# 3        nanzhang chengguanzhen  31.7839  111.8275     24.86        74
# 4                      tazovsky  67.4667   78.7000     12.20        71
# 6                        itoman  26.1247  127.6694     30.43        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                96        3.98      RU  1693217550
# 2                75        9.00      KZ  1693217552
# 3                59        1.74      CN  1693217553
# 4                62        2.58      RU  1693217554
# 6                40        4.12      JP  1693217557

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  gizo  -8.1030  156.8419     26.50        83         100
# 5        margaret river -33.9500  115.0667     14.02        75          98
# 7             whangarei -35.7317  174.3239      6.45        94           9
# 8          richards bay -28.7830   32.0377     21.15        55           5
# 9            bredasdorp -34.5322   20.0403     20.63        47           0
#
#          Wind Speed Country        Date
# City_ID
# 0              8.31      SB  1693217548
# 5              5.34      AU  1693217124
# 7              1.14      NZ  1693217498
# 8              3.32      ZA  1693217559
# 9              2.78      ZA  1693217561

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
print(f"r-value is {rvalue}")
plt.show()
# Out:
# r-value is -0.6651001457849318

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,-5),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
print(f"r-value is {rvalue}")
plt.show()
# Out:
# r-value is 0.7772698053167103

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear regression on Northern Hemisphere shows a negativeslope whereas the linear regression on Southern Hemisphere has a positive slope.Therefore, as shown on both graphs, if the city is getting close to latitudezero, its maximum temperature increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
print(f"r-value is {rvalue}")
plt.show()
# Out:
# r-value is 0.030327818821167283

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
print(f"r-value is {rvalue}")
plt.show()
# Out:
# r-value is 0.04116529234711793

# %% [markdown]
# **Discussion about the linear relationship:**
# Unlike the linear regression for Temperature vs. Latitude, the humidity does not show a strong tendency for both hemispheres. On the northern and southern hemispheres, the linear regression has a positive but low slope indicating that independently of the latitude, humidity is relatively stable.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,10),fontsize=15,color="red")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
print(f"r-value is {rvalue}")
plt.show()
# Out:
# r-value is 0.12781123160600819

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
print(f"r-value is {rvalue}")
plt.show()
# Out:
# r-value is -0.009065357025371283

# %% [markdown]
# **Discussion about the linear relationship:**
# Even though the northern hemisphere linear regression is showing behaviour that might confirm our premise, the southern hemisphere contradicts it by showing an increase in cloudiness at zero latitudes. As the r-value is too little for both regressions, we might consider these graphs irrelevant as they show a weak linear correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,15),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
print(f"r-value is {rvalue}")
plt.show()
# Out:
# r-value is -0.1333529669214512

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
print(f"r-value is {rvalue}")
plt.show()
# Out:
# r-value is -0.13314516844445606

# %% [markdown]
# **Discussion about the linear relationship:**
# Wind speed vs. Latitude linear regression shows less wind speed when the city is close to latitude zero independently of the hemisphere. Using this regression and the Temperature vs. Latitude, allows us to conclude that hotter temperatures are present on latitudes closer to zero.
