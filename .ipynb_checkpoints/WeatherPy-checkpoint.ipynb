# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
print(tuple(lat_lngs))
# Out:
# Number of cities in the list: 602
# ()

# %%
url = "https://api.openweathermap.org/data/2.5/weather?q="
city = "tonga"
units = "metric"

params = {
    "appid":weather_api_key,
    "units":"metric"
}

query_url = url + city + "&units=metric"

response = requests.get(query_url, params=params).json()

print(response["dt"])
print(json.dumps(response, indent=4, sort_keys=True))

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    params = {
        "appid":weather_api_key,
        "units":"metric"
    }
    
    query_url = url + city
    response = requests.get(url + city, params=params).json()

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = response["weather"][0]["description"]

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_max_temp = response["main"]["temp_max"]
        city_humidity = response["main"]["humidity"]
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_date = response["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sault ste. marie
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | shingu
# Processing Record 4 of Set 1 | richards bay
# Processing Record 5 of Set 1 | rehoboth
# Processing Record 6 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 1 | castillos
# Processing Record 8 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 9 of Set 1 | aasiaat
# Processing Record 10 of Set 1 | nyandoma
# Processing Record 11 of Set 1 | wynyard
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | chernyshevskiy
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | nar'yan-mar
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 1 | kuhmo
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | afaahiti
# Processing Record 23 of Set 1 | cole harbour
# Processing Record 24 of Set 1 | xi'an
# Processing Record 25 of Set 1 | pacific grove
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | kununurra
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | chibougamau
# Processing Record 30 of Set 1 | iskateley
# Processing Record 31 of Set 1 | kone
# Processing Record 32 of Set 1 | kapuskasing
# Processing Record 33 of Set 1 | nova sintra
# Processing Record 34 of Set 1 | invercargill
# Processing Record 35 of Set 1 | jaumave
# Processing Record 36 of Set 1 | sodankyla
# Processing Record 37 of Set 1 | edinburgh of the seven seas
# Processing Record 38 of Set 1 | luderitz
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | olonkinbyen
# Processing Record 42 of Set 1 | bathsheba
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | waitangi
# Processing Record 45 of Set 1 | gulf shores
# Processing Record 46 of Set 1 | ebon
# Processing Record 47 of Set 1 | souillac
# Processing Record 48 of Set 1 | guiratinga
# Processing Record 49 of Set 1 | arno
# Processing Record 50 of Set 1 | taro
# Processing Record 0 of Set 2 | ushuaia
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | malvan
# Processing Record 3 of Set 2 | tembisa
# Processing Record 4 of Set 2 | port saint john's
# Processing Record 5 of Set 2 | stanley
# Processing Record 6 of Set 2 | enewetak
# Processing Record 7 of Set 2 | lardero
# Processing Record 8 of Set 2 | mamuju
# Processing Record 9 of Set 2 | fort bragg
# Processing Record 10 of Set 2 | hawaiian paradise park
# Processing Record 11 of Set 2 | talnakh
# Processing Record 12 of Set 2 | qaqortoq
# Processing Record 13 of Set 2 | alaghsas
# Processing Record 14 of Set 2 | dunedin
# Processing Record 15 of Set 2 | papatowai
# Processing Record 16 of Set 2 | howard springs
# Processing Record 17 of Set 2 | sabzevar
# Processing Record 18 of Set 2 | spring creek
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | weno
# Processing Record 22 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 23 of Set 2 | blackmans bay
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | chonchi
# Processing Record 26 of Set 2 | puerto baquerizo moreno
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | ballina
# Processing Record 30 of Set 2 | sinan
# Processing Record 31 of Set 2 | macapa
# Processing Record 32 of Set 2 | khilok
# Processing Record 33 of Set 2 | muroto-misakicho
# Processing Record 34 of Set 2 | camana
# Processing Record 35 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 36 of Set 2 | kavaratti
# Processing Record 37 of Set 2 | sunnyside
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | tura
# Processing Record 40 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 41 of Set 2 | vorgashor
# Processing Record 42 of Set 2 | stavanger
# Processing Record 43 of Set 2 | palmas
# Processing Record 44 of Set 2 | as sulayyil
# Processing Record 45 of Set 2 | bilibino
# Processing Record 46 of Set 2 | greenland
# Processing Record 47 of Set 2 | newman
# Processing Record 48 of Set 2 | berdigestyakh
# Processing Record 49 of Set 2 | sanawad
# Processing Record 0 of Set 3 | tateyama
# Processing Record 1 of Set 3 | salekhard
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | saint-joseph
# Processing Record 4 of Set 3 | rexburg
# Processing Record 5 of Set 3 | haiku-pauwela
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | margaret river
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | masterton
# Processing Record 10 of Set 3 | la'ie
# Processing Record 11 of Set 3 | cooma
# Processing Record 12 of Set 3 | sarmiento
# Processing Record 13 of Set 3 | turpan
# Processing Record 14 of Set 3 | hobyo
# Processing Record 15 of Set 3 | utrik
# Processing Record 16 of Set 3 | kingscliff
# Processing Record 17 of Set 3 | isle of lewis
# City not found. Skipping...
# Processing Record 18 of Set 3 | igarka
# Processing Record 19 of Set 3 | hami
# Processing Record 20 of Set 3 | zavitinsk
# Processing Record 21 of Set 3 | lobujya
# Processing Record 22 of Set 3 | nizhniy lomov
# Processing Record 23 of Set 3 | lazaro cardenas
# Processing Record 24 of Set 3 | lauro de freitas
# Processing Record 25 of Set 3 | harper
# Processing Record 26 of Set 3 | sisimiut
# Processing Record 27 of Set 3 | papao
# Processing Record 28 of Set 3 | ribeira grande
# Processing Record 29 of Set 3 | wailua homesteads
# Processing Record 30 of Set 3 | vega de alatorre
# Processing Record 31 of Set 3 | kawambwa
# Processing Record 32 of Set 3 | west fargo
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | vimmerby
# Processing Record 35 of Set 3 | al fuwayliq
# Processing Record 36 of Set 3 | chekmagush
# Processing Record 37 of Set 3 | west island
# Processing Record 38 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | whitehorse
# Processing Record 41 of Set 3 | alta
# Processing Record 42 of Set 3 | vrangel'
# Processing Record 43 of Set 3 | constantia
# Processing Record 44 of Set 3 | chala
# Processing Record 45 of Set 3 | darwin
# Processing Record 46 of Set 3 | gebeit
# Processing Record 47 of Set 3 | timaru
# Processing Record 48 of Set 3 | taoudenni
# Processing Record 49 of Set 3 | matehuala
# Processing Record 0 of Set 4 | sinabang
# Processing Record 1 of Set 4 | viedma
# Processing Record 2 of Set 4 | menongue
# Processing Record 3 of Set 4 | ouesso
# Processing Record 4 of Set 4 | katima mulilo
# Processing Record 5 of Set 4 | hasaki
# Processing Record 6 of Set 4 | brookings
# Processing Record 7 of Set 4 | kapa'a
# Processing Record 8 of Set 4 | camden
# Processing Record 9 of Set 4 | tando adam
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | lata
# Processing Record 12 of Set 4 | udachny
# Processing Record 13 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 4 | sarnen
# Processing Record 15 of Set 4 | port lincoln
# Processing Record 16 of Set 4 | sabang
# Processing Record 17 of Set 4 | dickinson
# Processing Record 18 of Set 4 | novodvinsk
# Processing Record 19 of Set 4 | vilyuchinsk
# Processing Record 20 of Set 4 | port elizabeth
# Processing Record 21 of Set 4 | kingman
# Processing Record 22 of Set 4 | coaldale
# Processing Record 23 of Set 4 | antonio enes
# Processing Record 24 of Set 4 | isafjordur
# Processing Record 25 of Set 4 | klyuchi
# Processing Record 26 of Set 4 | acarau
# Processing Record 27 of Set 4 | tshabong
# Processing Record 28 of Set 4 | mount isa
# Processing Record 29 of Set 4 | bargaal
# Processing Record 30 of Set 4 | huarmey
# Processing Record 31 of Set 4 | egilsstadir
# Processing Record 32 of Set 4 | san antonio de pale
# Processing Record 33 of Set 4 | uturoa
# Processing Record 34 of Set 4 | ancud
# Processing Record 35 of Set 4 | yangor
# City not found. Skipping...
# Processing Record 36 of Set 4 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 37 of Set 4 | turkmenbasy
# Processing Record 38 of Set 4 | ellettsville
# Processing Record 39 of Set 4 | san patricio
# Processing Record 40 of Set 4 | champerico
# Processing Record 41 of Set 4 | montes claros
# Processing Record 42 of Set 4 | pazarcik
# Processing Record 43 of Set 4 | nikolayevsk-on-amure
# Processing Record 44 of Set 4 | orapa
# Processing Record 45 of Set 4 | kingston
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | tralee
# Processing Record 48 of Set 4 | koungou
# Processing Record 49 of Set 4 | ode
# Processing Record 0 of Set 5 | karelichy
# Processing Record 1 of Set 5 | kavarna
# Processing Record 2 of Set 5 | broken hill
# Processing Record 3 of Set 5 | santa rosa
# Processing Record 4 of Set 5 | saipan
# Processing Record 5 of Set 5 | khajuraho group of monuments
# Processing Record 6 of Set 5 | cannonvale
# Processing Record 7 of Set 5 | al mutayrifi
# Processing Record 8 of Set 5 | illizi
# Processing Record 9 of Set 5 | nuuk
# Processing Record 10 of Set 5 | fang
# Processing Record 11 of Set 5 | hadibu
# Processing Record 12 of Set 5 | penzance
# Processing Record 13 of Set 5 | nyrob
# Processing Record 14 of Set 5 | rovaniemi
# Processing Record 15 of Set 5 | namtsy
# Processing Record 16 of Set 5 | sawakin
# Processing Record 17 of Set 5 | jamestown
# Processing Record 18 of Set 5 | rawson
# Processing Record 19 of Set 5 | lompoc
# Processing Record 20 of Set 5 | mossel bay
# Processing Record 21 of Set 5 | mahina
# Processing Record 22 of Set 5 | zaozersk
# Processing Record 23 of Set 5 | wanning
# Processing Record 24 of Set 5 | ovalle
# Processing Record 25 of Set 5 | yeniseysk
# Processing Record 26 of Set 5 | colonia
# Processing Record 27 of Set 5 | zhezqazghan
# Processing Record 28 of Set 5 | merizo village
# Processing Record 29 of Set 5 | moose jaw
# Processing Record 30 of Set 5 | dzuunharaa
# Processing Record 31 of Set 5 | pueblo nuevo
# Processing Record 32 of Set 5 | katsuura
# Processing Record 33 of Set 5 | keelung
# Processing Record 34 of Set 5 | inhambane
# Processing Record 35 of Set 5 | sonsorol village
# City not found. Skipping...
# Processing Record 36 of Set 5 | howrah
# Processing Record 37 of Set 5 | palembang
# Processing Record 38 of Set 5 | port alfred
# Processing Record 39 of Set 5 | ouellah
# City not found. Skipping...
# Processing Record 40 of Set 5 | par
# Processing Record 41 of Set 5 | tremonton
# Processing Record 42 of Set 5 | dudinka
# Processing Record 43 of Set 5 | bambari
# Processing Record 44 of Set 5 | sakaiminato
# Processing Record 45 of Set 5 | port mathurin
# Processing Record 46 of Set 5 | el nido
# Processing Record 47 of Set 5 | point pedro
# Processing Record 48 of Set 5 | krasnovishersk
# Processing Record 49 of Set 5 | dadonghai
# City not found. Skipping...
# Processing Record 0 of Set 6 | remire-montjoly
# Processing Record 1 of Set 6 | dhidhdhoo
# Processing Record 2 of Set 6 | sanming
# Processing Record 3 of Set 6 | nagqu
# Processing Record 4 of Set 6 | carboneras
# Processing Record 5 of Set 6 | freetown
# Processing Record 6 of Set 6 | behompy
# Processing Record 7 of Set 6 | mahibadhoo
# Processing Record 8 of Set 6 | mytilene
# Processing Record 9 of Set 6 | longyearbyen
# Processing Record 10 of Set 6 | floro
# Processing Record 11 of Set 6 | fortaleza
# Processing Record 12 of Set 6 | gamba
# Processing Record 13 of Set 6 | badger
# Processing Record 14 of Set 6 | qa'en
# Processing Record 15 of Set 6 | keflavik
# Processing Record 16 of Set 6 | vernon
# Processing Record 17 of Set 6 | samthar
# Processing Record 18 of Set 6 | prince rupert
# Processing Record 19 of Set 6 | kirkuk
# Processing Record 20 of Set 6 | anna regina
# Processing Record 21 of Set 6 | minas de marcona
# Processing Record 22 of Set 6 | pacasmayo
# Processing Record 23 of Set 6 | kitui
# Processing Record 24 of Set 6 | codrington
# Processing Record 25 of Set 6 | selfoss
# Processing Record 26 of Set 6 | machagai
# Processing Record 27 of Set 6 | college
# Processing Record 28 of Set 6 | kiunga
# Processing Record 29 of Set 6 | khandyga
# Processing Record 30 of Set 6 | minas de matahambre
# City not found. Skipping...
# Processing Record 31 of Set 6 | dawesville
# Processing Record 32 of Set 6 | tazovsky
# Processing Record 33 of Set 6 | ust-nera
# Processing Record 34 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 35 of Set 6 | san carlos
# Processing Record 36 of Set 6 | yen vinh
# Processing Record 37 of Set 6 | touros
# Processing Record 38 of Set 6 | cabedelo
# Processing Record 39 of Set 6 | gaiman
# Processing Record 40 of Set 6 | tionk essil
# Processing Record 41 of Set 6 | porto novo
# Processing Record 42 of Set 6 | winnemucca
# Processing Record 43 of Set 6 | maceio
# Processing Record 44 of Set 6 | ust-tsilma
# Processing Record 45 of Set 6 | forster
# Processing Record 46 of Set 6 | happy valley-goose bay
# Processing Record 47 of Set 6 | rozhyshche
# Processing Record 48 of Set 6 | nuku'alofa
# Processing Record 49 of Set 6 | tofol
# Processing Record 0 of Set 7 | chapaev
# Processing Record 1 of Set 7 | canutama
# Processing Record 2 of Set 7 | boerne
# Processing Record 3 of Set 7 | livingston
# Processing Record 4 of Set 7 | santana
# Processing Record 5 of Set 7 | maputo
# Processing Record 6 of Set 7 | lodja
# Processing Record 7 of Set 7 | panacan
# Processing Record 8 of Set 7 | gadzhiyevo
# Processing Record 9 of Set 7 | puerto ayora
# Processing Record 10 of Set 7 | oranjemund
# Processing Record 11 of Set 7 | puerto colombia
# Processing Record 12 of Set 7 | coroata
# Processing Record 13 of Set 7 | revda
# Processing Record 14 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 7 | demyansk
# Processing Record 16 of Set 7 | argostolion
# Processing Record 17 of Set 7 | cobija
# Processing Record 18 of Set 7 | alpena
# Processing Record 19 of Set 7 | atafu village
# Processing Record 20 of Set 7 | krasnyy yar
# Processing Record 21 of Set 7 | tartu
# Processing Record 22 of Set 7 | guadalupe y calvo
# Processing Record 23 of Set 7 | tshela
# Processing Record 24 of Set 7 | new ulm
# Processing Record 25 of Set 7 | sao gabriel da cachoeira
# Processing Record 26 of Set 7 | mananara
# Processing Record 27 of Set 7 | tual
# Processing Record 28 of Set 7 | tazacorte
# Processing Record 29 of Set 7 | ihosy
# Processing Record 30 of Set 7 | karratha
# Processing Record 31 of Set 7 | nanao
# Processing Record 32 of Set 7 | kikwit
# Processing Record 33 of Set 7 | miechow
# Processing Record 34 of Set 7 | guajara
# Processing Record 35 of Set 7 | finale ligure
# Processing Record 36 of Set 7 | imbituba
# Processing Record 37 of Set 7 | vila do maio
# Processing Record 38 of Set 7 | celestun
# Processing Record 39 of Set 7 | nuriootpa
# Processing Record 40 of Set 7 | akureyri
# Processing Record 41 of Set 7 | hamilton
# Processing Record 42 of Set 7 | gizo
# Processing Record 43 of Set 7 | naze
# Processing Record 44 of Set 7 | alice springs
# Processing Record 45 of Set 7 | fale old settlement
# Processing Record 46 of Set 7 | lihue
# Processing Record 47 of Set 7 | gallup
# Processing Record 48 of Set 7 | vadso
# Processing Record 49 of Set 7 | beira
# Processing Record 0 of Set 8 | maracacume
# Processing Record 1 of Set 8 | island harbour
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | garh maharaja
# Processing Record 4 of Set 8 | portland
# Processing Record 5 of Set 8 | ijuw
# City not found. Skipping...
# Processing Record 6 of Set 8 | cold lake
# Processing Record 7 of Set 8 | maintirano
# Processing Record 8 of Set 8 | buka
# Processing Record 9 of Set 8 | 'izbat al burj
# City not found. Skipping...
# Processing Record 10 of Set 8 | scottburgh
# Processing Record 11 of Set 8 | concepcion
# Processing Record 12 of Set 8 | tommot
# Processing Record 13 of Set 8 | inarajan village
# Processing Record 14 of Set 8 | buenavista
# Processing Record 15 of Set 8 | walvis bay
# Processing Record 16 of Set 8 | kourou
# Processing Record 17 of Set 8 | bangjun
# Processing Record 18 of Set 8 | thinadhoo
# Processing Record 19 of Set 8 | fort-shevchenko
# Processing Record 20 of Set 8 | posto fiscal rolim de moura
# Processing Record 21 of Set 8 | onega
# Processing Record 22 of Set 8 | sabrum
# Processing Record 23 of Set 8 | mount pearl
# Processing Record 24 of Set 8 | umm kaddadah
# Processing Record 25 of Set 8 | santo domingo de la calzada
# Processing Record 26 of Set 8 | kismayo
# Processing Record 27 of Set 8 | mana
# Processing Record 28 of Set 8 | punta arenas
# Processing Record 29 of Set 8 | tolanaro
# Processing Record 30 of Set 8 | new plymouth
# Processing Record 31 of Set 8 | holbrook
# Processing Record 32 of Set 8 | nabire
# Processing Record 33 of Set 8 | virginia beach
# Processing Record 34 of Set 8 | nova vicosa
# Processing Record 35 of Set 8 | wawa
# Processing Record 36 of Set 8 | lipsko
# Processing Record 37 of Set 8 | luwuk
# Processing Record 38 of Set 8 | akjoujt
# Processing Record 39 of Set 8 | jindrichuv hradec
# Processing Record 40 of Set 8 | tsiombe
# Processing Record 41 of Set 8 | hujra shah muqim
# Processing Record 42 of Set 8 | sitia
# Processing Record 43 of Set 8 | lorengau
# Processing Record 44 of Set 8 | manta
# Processing Record 45 of Set 8 | tabora
# Processing Record 46 of Set 8 | irituia
# Processing Record 47 of Set 8 | flin flon
# Processing Record 48 of Set 8 | beboto
# Processing Record 49 of Set 8 | angaur state
# Processing Record 0 of Set 9 | urmary
# Processing Record 1 of Set 9 | phang nga
# Processing Record 2 of Set 9 | nguigmi
# Processing Record 3 of Set 9 | antsiranana
# Processing Record 4 of Set 9 | fada
# Processing Record 5 of Set 9 | nelson
# Processing Record 6 of Set 9 | boca do acre
# Processing Record 7 of Set 9 | ghat
# Processing Record 8 of Set 9 | mbandaka
# Processing Record 9 of Set 9 | wa
# City not found. Skipping...
# Processing Record 10 of Set 9 | aqaba
# Processing Record 11 of Set 9 | borovskoy
# Processing Record 12 of Set 9 | chui
# Processing Record 13 of Set 9 | loikaw
# Processing Record 14 of Set 9 | nadym
# Processing Record 15 of Set 9 | crane
# Processing Record 16 of Set 9 | tomatlan
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | quatre cocos
# Processing Record 19 of Set 9 | abepura
# Processing Record 20 of Set 9 | fortuna
# Processing Record 21 of Set 9 | bodo
# Processing Record 22 of Set 9 | suhbaatar
# Processing Record 23 of Set 9 | al mijlad
# Processing Record 24 of Set 9 | oranjestad
# Processing Record 25 of Set 9 | bel ombre
# Processing Record 26 of Set 9 | selibaby
# Processing Record 27 of Set 9 | berriane
# Processing Record 28 of Set 9 | kerikeri
# Processing Record 29 of Set 9 | mil'kovo
# Processing Record 30 of Set 9 | vila velha
# Processing Record 31 of Set 9 | cabezon de la sal
# Processing Record 32 of Set 9 | altay
# Processing Record 33 of Set 9 | karlovo
# Processing Record 34 of Set 9 | mukalla
# Processing Record 35 of Set 9 | ola
# Processing Record 36 of Set 9 | belmonte
# Processing Record 37 of Set 9 | aspen
# Processing Record 38 of Set 9 | awjilah
# Processing Record 39 of Set 9 | tchintabaraden
# Processing Record 40 of Set 9 | gowurdak
# Processing Record 41 of Set 9 | leua
# Processing Record 42 of Set 9 | sofifi
# City not found. Skipping...
# Processing Record 43 of Set 9 | lepsy
# Processing Record 44 of Set 9 | arraial do cabo
# Processing Record 45 of Set 9 | njombe
# Processing Record 46 of Set 9 | hammerfest
# Processing Record 47 of Set 9 | winkler
# Processing Record 48 of Set 9 | anahuac
# Processing Record 49 of Set 9 | usakos
# Processing Record 0 of Set 10 | luanda
# Processing Record 1 of Set 10 | valparaiso
# Processing Record 2 of Set 10 | santa rosa del sara
# City not found. Skipping...
# Processing Record 3 of Set 10 | mariental
# Processing Record 4 of Set 10 | glushkovo
# Processing Record 5 of Set 10 | isangel
# Processing Record 6 of Set 10 | bayganin
# Processing Record 7 of Set 10 | qarauyl
# Processing Record 8 of Set 10 | ad darb
# Processing Record 9 of Set 10 | port macquarie
# Processing Record 10 of Set 10 | lethem
# Processing Record 11 of Set 10 | carbondale
# Processing Record 12 of Set 10 | mahbubabad
# Processing Record 13 of Set 10 | middelburg
# Processing Record 14 of Set 10 | hithadhoo
# Processing Record 15 of Set 10 | san luis de la loma
# Processing Record 16 of Set 10 | rio grande
# Processing Record 17 of Set 10 | susanville
# Processing Record 18 of Set 10 | sangmelima
# Processing Record 19 of Set 10 | morant bay
# Processing Record 20 of Set 10 | hirara
# Processing Record 21 of Set 10 | nemuro
# Processing Record 22 of Set 10 | el calafate
# Processing Record 23 of Set 10 | roma
# Processing Record 24 of Set 10 | korla
# Processing Record 25 of Set 10 | brandfort
# Processing Record 26 of Set 10 | sao jose da coroa grande
# Processing Record 27 of Set 10 | north lakhimpur
# Processing Record 28 of Set 10 | youhao
# Processing Record 29 of Set 10 | bridgewater
# Processing Record 30 of Set 10 | dundalk
# Processing Record 31 of Set 10 | el granada
# Processing Record 32 of Set 10 | vallenar
# Processing Record 33 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 34 of Set 10 | babu
# Processing Record 35 of Set 10 | susuman
# Processing Record 36 of Set 10 | salinas
# Processing Record 37 of Set 10 | genhe
# Processing Record 38 of Set 10 | sinop
# Processing Record 39 of Set 10 | bettiah
# Processing Record 40 of Set 10 | sona
# Processing Record 41 of Set 10 | yakeshi
# Processing Record 42 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 43 of Set 10 | holly springs
# Processing Record 44 of Set 10 | mohr
# Processing Record 45 of Set 10 | isla mujeres
# Processing Record 46 of Set 10 | bhattarai danda
# Processing Record 47 of Set 10 | tharad
# Processing Record 48 of Set 10 | oppdal
# Processing Record 49 of Set 10 | kizner
# Processing Record 0 of Set 11 | fauske
# Processing Record 1 of Set 11 | fort st. john
# Processing Record 2 of Set 11 | podenzano
# Processing Record 3 of Set 11 | zheshart
# Processing Record 4 of Set 11 | aykhal
# Processing Record 5 of Set 11 | alofi
# Processing Record 6 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 7 of Set 11 | guntakal junction
# Processing Record 8 of Set 11 | bambanglipuro
# Processing Record 9 of Set 11 | west bay
# Processing Record 10 of Set 11 | paramonga
# Processing Record 11 of Set 11 | pyay
# Processing Record 12 of Set 11 | puerto santa
# Processing Record 13 of Set 11 | miles city
# Processing Record 14 of Set 11 | talara
# Processing Record 15 of Set 11 | cairns city
# City not found. Skipping...
# Processing Record 16 of Set 11 | dolores
# Processing Record 17 of Set 11 | vaasa
# Processing Record 18 of Set 11 | kyren
# Processing Record 19 of Set 11 | awsim
# Processing Record 20 of Set 11 | yankton
# Processing Record 21 of Set 11 | al jawf
# Processing Record 22 of Set 11 | picui
# Processing Record 23 of Set 11 | la cruz
# Processing Record 24 of Set 11 | coahuayana de hidalgo
# Processing Record 25 of Set 11 | acapulco de juarez
# Processing Record 26 of Set 11 | feodosiya
# Processing Record 27 of Set 11 | sechura
# Processing Record 28 of Set 11 | dauphin
# Processing Record 29 of Set 11 | iwanai
# Processing Record 30 of Set 11 | isna
# Processing Record 31 of Set 11 | conceicao do coite
# Processing Record 32 of Set 11 | christchurch
# Processing Record 33 of Set 11 | holualoa
# Processing Record 34 of Set 11 | angra do heroismo
# Processing Record 35 of Set 11 | bikenibeu village
# Processing Record 36 of Set 11 | nanlong
# Processing Record 37 of Set 11 | oyama
# Processing Record 38 of Set 11 | palikir - national government center
# Processing Record 39 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 40 of Set 11 | manali
# Processing Record 41 of Set 11 | whitby
# Processing Record 42 of Set 11 | severodvinsk
# Processing Record 43 of Set 11 | bibbiena
# Processing Record 44 of Set 11 | birjand
# Processing Record 45 of Set 11 | rajgarh
# Processing Record 46 of Set 11 | suva
# Processing Record 47 of Set 11 | itoman
# Processing Record 48 of Set 11 | cambria
# Processing Record 49 of Set 11 | thoen
# Processing Record 0 of Set 12 | bure
# Processing Record 1 of Set 12 | abra pampa
# Processing Record 2 of Set 12 | abashiri
# Processing Record 3 of Set 12 | smara
# Processing Record 4 of Set 12 | barah
# Processing Record 5 of Set 12 | lerwick
# Processing Record 6 of Set 12 | borcka
# Processing Record 7 of Set 12 | shakawe
# Processing Record 8 of Set 12 | siwa oasis
# Processing Record 9 of Set 12 | san-pedro
# Processing Record 10 of Set 12 | chaman
# Processing Record 11 of Set 12 | tashtyp
# Processing Record 12 of Set 12 | callao
# Processing Record 13 of Set 12 | krasnyy chikoy
# Processing Record 14 of Set 12 | conception bay south
# Processing Record 15 of Set 12 | kudahuvadhoo
# Processing Record 16 of Set 12 | bandundu
# Processing Record 17 of Set 12 | an nimas
# Processing Record 18 of Set 12 | chernyshevsk
# Processing Record 19 of Set 12 | fort mcmurray
# Processing Record 20 of Set 12 | chinchilla
# Processing Record 21 of Set 12 | dwarka
# Processing Record 22 of Set 12 | mudurnu
# Processing Record 23 of Set 12 | tarija
# Processing Record 24 of Set 12 | orvieto
# Processing Record 25 of Set 12 | meadow lakes
# Processing Record 26 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 27 of Set 12 | filadelfia
# Processing Record 28 of Set 12 | laguna
# Processing Record 29 of Set 12 | la passe
# Processing Record 30 of Set 12 | shipunovo
# Processing Record 31 of Set 12 | roccella ionica
# Processing Record 32 of Set 12 | kabansk
# Processing Record 33 of Set 12 | sanctuary point
# Processing Record 34 of Set 12 | basco
# Processing Record 35 of Set 12 | puerto esperanza
# Processing Record 36 of Set 12 | cheremukhovo
# Processing Record 37 of Set 12 | tadine
# Processing Record 38 of Set 12 | kenai
# Processing Record 39 of Set 12 | higuera de zaragoza
# Processing Record 40 of Set 12 | ambalangoda
# Processing Record 41 of Set 12 | ringkobing
# Processing Record 42 of Set 12 | lae
# Processing Record 43 of Set 12 | padre las casas
# Processing Record 44 of Set 12 | chabahar
# Processing Record 45 of Set 12 | turka
# Processing Record 46 of Set 12 | merowe
# Processing Record 47 of Set 12 | wulingyuan
# Processing Record 48 of Set 12 | puerto deseado
# Processing Record 49 of Set 12 | constitucion
# Processing Record 0 of Set 13 | south hedland
# Processing Record 1 of Set 13 | moree
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data

city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  sault ste. marie  46.5168  -84.3333     18.16        90          75
# 1    puerto natales -51.7236  -72.4875     -0.27        92          60
# 2            shingu  33.7333  135.9833     28.98        71           8
# 3      richards bay -28.7830   32.0377     19.57        76           0
# 4          rehoboth -23.3167   17.0833      7.07        36         100
#
#    Wind Speed Country        Date
# 0        6.17      CA  1693013473
# 1        2.16      CL  1693013474
# 2        3.96      JP  1693013475
# 3        4.83      ZA  1693013476
# 4        3.28      NA  1693013410

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
date = datetime.date.fromtimestamp(city_data_df["Date"][0])
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        sault ste. marie  46.5168  -84.3333     18.16        90          75
# 1          puerto natales -51.7236  -72.4875     -0.27        92          60
# 2                  shingu  33.7333  135.9833     28.98        71           8
# 3            richards bay -28.7830   32.0377     19.57        76           0
# 4                rehoboth -23.3167   17.0833      7.07        36         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      CA  1693013473
# 1              2.16      CL  1693013474
# 2              3.96      JP  1693013475
# 3              4.83      ZA  1693013476
# 4              3.28     NaN  1693013410

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
y_axis = city_data_df["Lat"]
x_axis = city_data_df["Max Temp"]
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.ylabel("Max Temperature (°C)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs Max Temperature ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
y_axis = city_data_df["Lat"]
x_axis = city_data_df["Humidity"]
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs Humidity ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
y_axis = city_data_df["Lat"]
x_axis = city_data_df["Cloudiness"]
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs Cloudiness ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
y_axis = city_data_df["Lat"]
x_axis = city_data_df["Wind Speed"]
plt.scatter(x_axis, y_axis, edgecolors="black")

# Incorporate the other graph properties
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs Wind Speed ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
y_values = city_data_df["Lat"]
x_values = city_data_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
line_eq
# Out:
# 'y = -2.28x + 26.46'

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                sault ste. marie  46.5168  -84.3333     18.16        90
# 2                          shingu  33.7333  135.9833     28.98        71
# 5        petropavlovsk-kamchatsky  53.0452  158.6483     15.33        82
# 7                         aasiaat  68.7098  -52.8699      2.89        93
# 8                        nyandoma  61.6690   40.1991      7.41        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75        6.17      CA  1693013473
# 2                 8        3.96      JP  1693013475
# 5               100        2.00      RU  1693013381
# 7               100        5.50      GL  1693013482
# 8               100        1.95      RU  1693013483

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        puerto natales -51.7236  -72.4875     -0.27        92          60
# 3          richards bay -28.7830   32.0377     19.57        76           0
# 4              rehoboth -23.3167   17.0833      7.07        36         100
# 6             castillos -34.1667  -53.8333      5.30        75           0
# 9               wynyard -41.0000  145.7167     11.27        54          87
#
#          Wind Speed Country        Date
# City_ID
# 1              2.16      CL  1693013474
# 3              4.83      ZA  1693013476
# 4              3.28     NaN  1693013410
# 6              3.24      UY  1693013480
# 9              2.95      AU  1693013484

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
y_values = northern_hemi_df["Lat"]
x_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,15),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.show()

# %%
# Linear regression on Southern Hemisphere
y_values = southern_hemi_df["Lat"]
x_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-5),fontsize=15,color="red")
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
y_values = northern_hemi_df["Lat"]
x_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,10),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.show()

# %%
# Southern Hemisphere
y_values = southern_hemi_df["Lat"]
x_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,-50),fontsize=15,color="red")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
y_values = northern_hemi_df["Lat"]
x_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,10),fontsize=15,color="red")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.show()

# %%
# Southern Hemisphere
y_values = southern_hemi_df["Lat"]
x_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
y_values = northern_hemi_df["Lat"]
x_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,0),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.show()

# %%
# Southern Hemisphere
y_values = southern_hemi_df["Lat"]
x_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,-50),fontsize=15,color="red")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
